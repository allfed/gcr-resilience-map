# %% [markdown]
# # Paper Processing System
#
# This notebook processes academic papers to extract information about regional resilience to catastrophic risks using Claude.
#
# ## Setup
#
# First, let's import all required libraries and set up logging.

# %%
# Import required libraries
import os
from pathlib import Path
import PyPDF2
import anthropic
import pandas as pd
from tqdm import tqdm
import tiktoken
import csv
import json
from io import StringIO
import hashlib
import datetime
import time as sleep_time
import logging
from dataclasses import dataclass
from typing import List, Optional, Dict, Any, Set  # Added List and other type hints

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Data Structures and Classes
#
# Define the data structures and classes needed for processing papers.

# %%
@dataclass
class PaperMetadata:
    """Data class for paper metadata"""
    filename: str
    paper_citation: Optional[str] = None
    publication_type: Optional[str] = None
    gcr_types: Optional[str] = None
    geographic_focus: Optional[str] = None
    geographic_factors: Optional[str] = None
    institutional_factors: Optional[str] = None
    infrastructural_factors: Optional[str] = None
    other_resilience_factors: Optional[str] = None
    study_approach: Optional[str] = None
    resilience_phase: Optional[str] = None
    main_resilience_factors: Optional[str] = None
    resilience_tradeoffs: Optional[str] = None
    vulnerable_resilient_regions: Optional[str] = None
    overall_relevance: Optional[str] = None
    evidence_gaps: Optional[str] = None
    error: Optional[str] = None
    current_query: Optional[str] = None  # Added for token calculations

    def to_dict(self) -> Dict[str, Any]:
        """Convert to dictionary for storage, excluding current_query"""
        return {k: v for k, v in self.__dict__.items()
                if v is not None and k != 'current_query'}  # Exclude current_query

# %%
class PDFExtractor:
    """Extracts text from PDF files"""
    def extract(self, file_path: Path) -> str:
        """Extract text from a PDF file"""
        with open(file_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            text = ""
            for page in reader.pages:
                text += page.extract_text() + "\n"
        return text

class Tokenizer:
    """Handles text tokenization and truncation"""
    def __init__(self, encoding_name: str = "cl100k_base"):
        self.encoding = tiktoken.get_encoding(encoding_name)
    
    def count_tokens(self, text: str) -> int:
        """Count tokens in text"""
        return len(self.encoding.encode(text))
    
    def truncate(self, text: str, ratio: float) -> str:
        """Truncate text to a given ratio of its original length"""
        tokens = self.encoding.encode(text)
        return self.encoding.decode(tokens[:int(len(tokens) * ratio)])

# %%
class ClaudeClient:
    """Client for Claude API"""
    def __init__(self, api_key: str, model: str = "claude-3-7-sonnet-20250219"):
        self.client = anthropic.Anthropic(api_key=api_key)
        self.model = model
    
    def process_text(self, text: str, query: str, **kwargs) -> str:
        """Process text with Claude"""
        response = self.client.messages.create(
            model=self.model,
            max_tokens=kwargs.get('max_tokens', 1000),
            temperature=kwargs.get('temperature', 0),
            system=[{"type": "text", "text": "You are an AI assistant tasked with analyzing documents."}],
            messages=[{"role": "user", "content": f"Document content:\n{text}\n\n{query}"}]
        )
        return response.content[0].text

# %%
class FileCache:
    """Simple file-based cache"""
    def __init__(self, cache_file: Path):
        self.cache_file = cache_file
        self.cache: Dict[str, str] = {}
        self._load_cache()
    
    def _load_cache(self) -> None:
        """Load cache from file"""
        if self.cache_file.exists():
            with open(self.cache_file, 'r') as f:
                self.cache = json.load(f)
    
    def _save_cache(self) -> None:
        """Save cache to file"""
        with open(self.cache_file, 'w') as f:
            json.dump(self.cache, f)
    
    def get(self, key: str) -> Optional[str]:
        """Get cached response"""
        return self.cache.get(key)
    
    def set(self, key: str, value: str) -> None:
        """Cache a response"""
        self.cache[key] = value
        self._save_cache()


class CSVStorage:
    """Handles storage of results in CSV format"""

    def __init__(self, output_file: Path):
        self.output_file = output_file
        self._ensure_file_exists()

    def _ensure_file_exists(self):
        if not self.output_file.exists():
            # Create empty file with headers
            df = pd.DataFrame(columns=PaperMetadata.__annotations__.keys())
            df.to_csv(self.output_file, index=False)

    def is_processed(self, filename: str) -> bool:
        """Check if a file has already been processed"""
        try:
            if not self.output_file.exists():
                return False
            df = pd.read_csv(self.output_file)
            return filename in df['filename'].values
        except Exception as e:
            logger.error(f"Error checking if file is processed: {str(e)}")
            return False

    def get_processed_files(self) -> set:
        """Get set of all processed filenames"""
        try:
            if not self.output_file.exists():
                return set()
            df = pd.read_csv(self.output_file)
            return set(df['filename'].values)
        except Exception as e:
            logger.error(f"Error getting processed files: {str(e)}")
            return set()

    def save_results(self, results: List[PaperMetadata]):
        """Save results to CSV file"""
        try:
            df = pd.DataFrame([r.to_dict() for r in results])
            df.to_csv(self.output_file, index=False)
        except Exception as e:
            logger.error(f"Error saving results: {str(e)}")

# %%
class PaperProcessor:
    """Main paper processing class"""

    def __init__(
        self,
        text_extractor: PDFExtractor,
        tokenizer: Tokenizer,
        llm_client: ClaudeClient,
        cache: FileCache,
        storage: CSVStorage,
        max_tokens: int = 4000,
        truncation_ratio: float = 0.8,
        tokens_per_minute: int = 20000,  # Claude's rate limit
        max_total_tokens: int = 200000   # Claude's total token limit
    ):
        self.text_extractor = text_extractor
        self.tokenizer = tokenizer
        self.llm_client = llm_client
        self.cache = cache
        self.storage = storage
        self.max_tokens = max_tokens
        self.truncation_ratio = truncation_ratio
        self.tokens_per_minute = tokens_per_minute
        self.max_total_tokens = max_total_tokens

        # Rate limiting tracking
        self.token_usage = []  # List of (timestamp, token_count) tuples

        # Calculate prompt tokens once
        self.prompt_tokens = self.tokenizer.count_tokens(
            "Document content:\n\n" +  # Base prompt
            "You are an AI assistant tasked with analyzing documents."  # System prompt
        )

    def _calculate_max_paper_tokens(self) -> int:
        """Calculate maximum tokens allowed for the paper text"""
        # Reserve space for the query and other prompt elements
        query_tokens = self.tokenizer.count_tokens(self.current_query)
        reserved_tokens = self.prompt_tokens + query_tokens + 1000  # Add buffer
        return self.max_total_tokens - reserved_tokens

    def _cleanup_old_usage(self):
        """Remove token usage records older than 1 minute"""
        current_time = datetime.datetime.now()
        one_minute_ago = current_time - datetime.timedelta(minutes=1)
        self.token_usage = [(ts, count) for ts, count in self.token_usage if ts > one_minute_ago]

    def _get_current_token_usage(self) -> int:
        """Get total token usage in the last minute"""
        self._cleanup_old_usage()
        return sum(count for _, count in self.token_usage)

    def _wait_for_rate_limit(self, required_tokens: int):
        """Wait if necessary to stay within rate limits"""
        while True:
            current_usage = self._get_current_token_usage()
            if current_usage + required_tokens <= self.tokens_per_minute:
                break
            
            # Check if we have any usage records
            if not self.token_usage:
                # If no records, we can proceed
                break
                
            # Calculate how long to wait
            oldest_record = min(ts for ts, _ in self.token_usage)
            wait_time = 60
            if wait_time > 0:
                logger.info(f"Rate limit reached. Waiting {wait_time:.1f} seconds...")
                sleep_time.sleep(wait_time)
            self._cleanup_old_usage()

    def _record_token_usage(self, token_count: int):
        """Record token usage for rate limiting"""
        self.token_usage.append((datetime.datetime.now(), token_count))

    def process_paper(self, file_path: Path, query: str) -> PaperMetadata:
        """Process a single paper"""
        # Store query for token calculations
        self.current_query = query

        # Extract text
        text = self.text_extractor.extract(file_path)
        logger.info(f"Extracted {len(text)} characters from {file_path.name}")

        # Check cache
        cache_key = hashlib.md5((text + query).encode()).hexdigest()
        if cached_response := self.cache.get(cache_key):
            logger.info(f"Using cached response for {file_path.name}")
            return self._parse_response(cached_response, file_path.name)

        # Process with LLM
        current_text = text
        while True:
            try:
                # Check rate limit and wait if necessary
                total_tokens = self.tokenizer.count_tokens(current_text) + self.prompt_tokens + self.tokenizer.count_tokens(query)
                self._wait_for_rate_limit(total_tokens)
                
                # Try to process
                response = self.llm_client.process_text(current_text, query)
                self._record_token_usage(total_tokens)
                self.cache.set(cache_key, response)
                return self._parse_response(response, file_path.name)
                
            except Exception as e:
                if "too long" in str(e).lower():
                    # Truncate to 80% of current length
                    current_tokens = self.tokenizer.count_tokens(current_text)
                    target_tokens = int(current_tokens * self.truncation_ratio)
                    target_tokens = max(1000, target_tokens)  # Ensure minimum length
                    
                    logger.info(f"Token limit exceeded. Truncating from {current_tokens} to {target_tokens} tokens...")
                    tokens = self.tokenizer.encoding.encode(current_text)
                    current_text = self.tokenizer.encoding.decode(tokens[:target_tokens])
                else:
                    raise e
                
    def _parse_response(self, response: str, filename: str) -> PaperMetadata:
        """Parse CSV response into PaperMetadata object"""
        try:
            # Clean the response text
            clean_text = response.strip()
            
            # Find the first line that looks like a CSV row (has multiple commas)
            # and doesn't contain the prompt text
            lines = clean_text.split('\n')
            csv_line = None
            for line in lines:
                # Skip lines that contain parts of the prompt
                if "research question" in line.lower() or "csv format" in line.lower():
                    continue
                # Find the line with the most commas that's not the prompt
                if line.count(',') >= 10:  # We expect at least 10 commas for our CSV format
                    csv_line = line
                    break
            
            if not csv_line:
                raise ValueError("No valid CSV line found in response")
            
            # Parse CSV
            reader = csv.reader(StringIO(csv_line))
            row = next(reader)
            
            # Create PaperMetadata object with all fields
            return PaperMetadata(
                filename=filename,
                paper_citation=row[0] if len(row) > 0 else None,
                publication_type=row[1] if len(row) > 1 else None,
                gcr_types=row[2] if len(row) > 2 else None,
                geographic_focus=row[3] if len(row) > 3 else None,
                geographic_factors=row[4] if len(row) > 4 else None,
                institutional_factors=row[5] if len(row) > 5 else None,
                infrastructural_factors=row[6] if len(row) > 6 else None,
                other_resilience_factors=row[7] if len(row) > 7 else None,
                study_approach=row[8] if len(row) > 8 else None,
                resilience_phase=row[9] if len(row) > 9 else None,
                main_resilience_factors=row[10] if len(row) > 10 else None,
                resilience_tradeoffs=row[11] if len(row) > 11 else None,
                vulnerable_resilient_regions=row[12] if len(row) > 12 else None,
                overall_relevance=row[13] if len(row) > 13 else None,
                evidence_gaps=row[14] if len(row) > 14 else None,
                current_query=self.current_query
            )
        except Exception as e:
            logger.error(f"Error parsing response for {filename}: {str(e)}")
            return PaperMetadata(filename=filename, error=str(e))
                
    def process_directory(self, directory: Path, query: str) -> None:
        """Process all PDF files in a directory"""
        results = []
        pdf_files = list(directory.glob("*.pdf"))
        
        for pdf_path in tqdm(pdf_files, desc="Processing PDFs"):
            try:
                # Skip if already processed
                if self.storage.is_processed(pdf_path.name):
                    logger.info(f"Loading cached results for: {pdf_path.name}")
                    # Extract text to generate same cache key
                    text = self.text_extractor.extract(pdf_path)
                    cache_key = hashlib.md5((text + query).encode()).hexdigest()
    
                    if cached_response := self.cache.get(cache_key):
                        self.current_query = query
                        result = self._parse_response(cached_response, pdf_path.name)
                        results.append(result)
                        continue
                else:
                    logger.warning(f"File {pdf_path.name} marked as processed but no cache found, reprocessing...")

                logger.info(f"Processing {pdf_path.name}...")
                result = self.process_paper(pdf_path, query)
                results.append(result)

                # Save after each successful processing
                self.storage.save_results(results)
                logger.info(f"Successfully processed {pdf_path.name}")

            except Exception as e:
                logger.error(f"Error processing {pdf_path.name}: {str(e)}")
                # Add error record
                error_result = PaperMetadata(
                    filename=pdf_path.name,
                    error=str(e)
                )
                results.append(error_result)
                # Save even after errors
                self.storage.save_results(results)

# %% [markdown]
# ## Configuration
#
# Set up the configuration and initialize components.

# %%
# Load API key
with open("../config/api_key.txt", 'r') as f:
    api_key = f.read().strip()

# Define extraction query
query = """I need you to analyze the provided research paper and extract specific information about regional resilience to catastrophic risks. Our research question is: "What specific geographical, institutional, and infrastructural factors have been empirically or theoretically identified as enhancing regional resilience to nuclear winter, large magnitude volcanic eruptions, extreme pandemics, and infrastructure collapse catastrophes, and how do these resilience factors vary across catastrophe types?"

After analyzing the paper thoroughly, provide your output in a single row CSV format with the following structure:

1. paper_citation: Full citation (author, year, title)
2. publication_type: [Journal article/Preprint/Report/Book chapter]
3. gcr_types: Types of catastrophic risks addressed [Nuclear/Volcanic/Asteroid/Infrastructure/Pandemic/Climate/Multiple]
4. geographic_focus: [Global/Regional/National/Local/Islands - specify]
5. geographic_factors: List key geographic factors (location, climate, resources, etc.)
6. institutional_factors: List key institutional factors (governance, policies, social systems, etc.)
7. infrastructural_factors: List key infrastructure factors (energy, food, communications, etc.)
8. other_resilience_factors: Any resilience factors not fitting above categories
9. study_approach: [Model/Empirical/Review/Case study/Theoretical]
10. resilience_phase: [Preparedness/Robustness/Recovery/Adaptation]
11. main_resilience_factors: Brief summary of main resilience-enhancing factors
12. resilience_tradeoffs: [Yes/No] with description of any identified trade-offs
13. vulnerable_resilient_regions: List of particularly vulnerable or resilient regions identified
14. overall_relevance: [Low/Medium/High] relevance to our research question
15. evidence_gaps: Brief description of critical missing validation elements

CRITICAL CSV FORMATTING REQUIREMENTS:

- Wrap ALL text fields in double quotes, even if they don't contain commas
- If a text field contains double quotes, escape them by doubling them ("")
- Use commas ONLY as field separators between fields
- Do not use any quotes within the field content except for properly escaped ones
- Each field must be enclosed in double quotes: "field content"

Example format: "text field 1","text field 2","text field 3"
The entire row should look like: "field1","field2","field3",...,"field15"

For fields with multiple options, use the exact values specified in brackets. Please analyze the paper thoroughly before extracting the information.
Respond with ONLY the CSV row (no column headers, no additional text).

For text fields, place the content in double quotes to properly handle any commas. For fields with multiple options, use the exact values specified in brackets. Please analyze the paper thoroughly before extracting the information. Respond with ONLY the CSV row (no column headers)."""

# %%
# Initialize components
text_extractor = PDFExtractor()
tokenizer = Tokenizer()
llm_client = ClaudeClient(api_key)
cache = FileCache(Path("prompt_cache/extraction_prompt_cache.json"))
storage = CSVStorage(Path("gcr_resilience_extraction_results.csv"))

# Create processor
processor = PaperProcessor(
    text_extractor=text_extractor,
    tokenizer=tokenizer,
    llm_client=llm_client,
    cache=cache,
    storage=storage
)

# %% [markdown]
# ## Process Papers
#
# Process all papers in the PDF directory.

# %%
# Process papers
processor.process_directory(Path("pdf"), query)
# Out:
# Processing PDFs:   0%|          | 0/147 [00:00<?, ?it/s]2025-06-16 22:23:49,854 - INFO - Loading cached results for: Tzachor - 2022 - A System Dynamics Perspective of Food Systems, Environmental Change and Global Catastrophic Risks.pdf
# Processing PDFs:   1%|          | 1/147 [00:00<00:38,  3.75it/s]2025-06-16 22:23:50,115 - INFO - Loading cached results for: Beckstead - 2015 - How much could refuges help us recover from a global catastrophe.pdf
# 2025-06-16 22:23:50,203 - INFO - Loading cached results for: Jones et al. - 2023 - Scoping Potential Routes to UK Civil Unrest via the Food System Results of a Structured Expert Elic 05.00.57.pdf
# Processing PDFs:   2%|▏         | 3/147 [00:00<00:22,  6.50it/s]2025-06-16 22:23:50,344 - INFO - Loading cached results for: Mani et al. - 2022 - Lower magnitude volcanic eruptions as Global Catastrophic Risks.pdf
# 2025-06-16 22:23:50,388 - INFO - Loading cached results for: Doran et al. - 2024 - What can we learn from historical pandemics A systematic review of the literature.pdf
# Processing PDFs:   3%|▎         | 5/147 [00:01<00:36,  3.92it/s]2025-06-16 22:23:51,046 - INFO - Loading cached results for: Räisänen et al. - 2023 - Imagining the next pandemic Finnish preparedness for chronic transboundary crises before and during.pdf
# Processing PDFs:   4%|▍         | 6/147 [00:01<00:32,  4.39it/s]2025-06-16 22:23:51,198 - INFO - Loading cached results for: Cockell and Stokes - 1999 - [No title found].pdf
# Processing PDFs:   5%|▍         | 7/147 [00:01<00:27,  5.09it/s]2025-06-16 22:23:51,314 - INFO - Loading cached results for: Baum - 2018 - Uncertain human consequences in asteroid risk analysis and the global catastrophe threshold.pdf
# Processing PDFs:   5%|▌         | 8/147 [00:01<00:27,  5.03it/s]2025-06-16 22:23:51,518 - INFO - Loading cached results for: Ledesma et al. - 2023 - Evaluation of the Global Health Security Index as a predictor of COVID-19 excess mortality standardi.pdf
# Processing PDFs:   6%|▌         | 9/147 [00:01<00:23,  5.79it/s]2025-06-16 22:23:51,626 - INFO - Loading cached results for: Cooper and Sovacool - 2011 - Not Your Father's Y2K Preparing the North American Power Grid for the Perfect Solar Storm.pdf
# 2025-06-16 22:23:51,697 - INFO - Loading cached results for: Luby and Arthur - 2019 - Risk and Response to Biological Catastrophe in Lower Income Countries.pdf
# Processing PDFs:   7%|▋         | 11/147 [00:01<00:17,  7.57it/s]2025-06-16 22:23:51,792 - INFO - Loading cached results for: Tonn and Stiefel - 2014 - Human extinction risk and uncertainty Assessing conditions for action.pdf
# Processing PDFs:   8%|▊         | 12/147 [00:02<00:21,  6.23it/s]2025-06-16 22:23:52,041 - INFO - Loading cached results for: Neogi et al. - 2021 - The predictors of COVID-19 mortality among health systems and Global Health Security parameters An.pdf
# Processing PDFs:   9%|▉         | 13/147 [00:02<00:40,  3.31it/s]2025-06-16 22:23:52,749 - INFO - Loading cached results for: García Martínez et al. - 2020 - Methane Single Cell Protein securing protein supply during global food catastrophes 05.00.57.pdf
# Processing PDFs:  10%|▉         | 14/147 [00:03<01:04,  2.05it/s]2025-06-16 22:23:53,738 - INFO - Loading cached results for: Baum et al. - 2015 - Resilience to global food supply catastrophes.pdf
# Processing PDFs:  10%|█         | 15/147 [00:06<02:05,  1.05it/s]2025-06-16 22:23:55,890 - INFO - Loading cached results for: Ayasreh - 2023 - Science Diplomacy, Global Catastrophic Risks, and Global Governance A Required Interaction.pdf
# Processing PDFs:  11%|█         | 16/147 [00:06<01:33,  1.40it/s]2025-06-16 22:23:56,008 - INFO - Loading cached results for: Jehn - 2025 - Anthropocene Under Dark Skies The Compounding Effects of Nuclear Winter and Overstepped Planetary B.pdf
# Processing PDFs:  12%|█▏        | 17/147 [00:06<01:20,  1.61it/s]2025-06-16 22:23:56,405 - INFO - Loading cached results for: Newhall et al. - 2018 - Anticipating future Volcanic Explosivity Index (VEI) 7 eruptions and their chilling impacts.pdf
# Processing PDFs:  12%|█▏        | 18/147 [00:06<01:09,  1.86it/s]2025-06-16 22:23:56,737 - INFO - Loading cached results for: Da Silva et al. - 2023 - National governance and excess mortality due to COVID-19 in 213 countries a retrospective analysis.pdf
# Processing PDFs:  13%|█▎        | 19/147 [00:07<00:55,  2.29it/s]2025-06-16 22:23:56,933 - INFO - Loading cached results for: Helbing - 2013 - Globally networked risks and how to respond 05.00.57.pdf
# Processing PDFs:  14%|█▎        | 20/147 [00:07<00:59,  2.15it/s]2025-06-16 22:23:57,466 - INFO - Loading cached results for: O’Hara - 2021 - Global coronavirus pandemic crisis and future crisis prevention.pdf
# Processing PDFs:  14%|█▍        | 21/147 [00:07<00:53,  2.34it/s]2025-06-16 22:23:57,806 - INFO - Loading cached results for: Amadu et al. - 2020 - Assessing Sub-Regional-Specific Strengths of Healthcare Systems Associated with COVID-19 Prevalence,.pdf
# Processing PDFs:  15%|█▍        | 22/147 [00:08<00:45,  2.77it/s]2025-06-16 22:23:58,008 - INFO - Loading cached results for: Lyu et al. - 2023 - One Pandemic, Two Solutions Comparing the U.S.-China Response and Health Priorities to COVID-19 fro.pdf
# Processing PDFs:  16%|█▌        | 23/147 [00:08<00:37,  3.31it/s]2025-06-16 22:23:58,174 - INFO - Loading cached results for: Schrijver - 2015 - Socio‐Economic Hazards and Impacts of Space Weather The Important Range Between Mild and Extreme 1.pdf
# 2025-06-16 22:23:58,252 - INFO - Loading cached results for: Yang and Sandberg - 2022 - Collective Intelligence as Infrastructure for Reducing Broad Global Catastrophic Risks.pdf
# Processing PDFs:  17%|█▋        | 25/147 [00:08<00:28,  4.27it/s]2025-06-16 22:23:58,483 - INFO - Loading cached results for: Veale and Endfield - 2016 - Situating 1816, the ‘year without summer’, in the UK.pdf
# Processing PDFs:  18%|█▊        | 26/147 [00:08<00:24,  4.97it/s]2025-06-16 22:23:58,584 - INFO - Loading cached results for: McLaughlin et al. - 2024 - Maladaptation in cereal crop landraces following a soot-producing climate catastrophe.pdf
# Processing PDFs:  18%|█▊        | 27/147 [00:08<00:25,  4.65it/s]2025-06-16 22:23:58,837 - INFO - Loading cached results for: Peregrine - 2021 - Social resilience to nuclear winter lessons from the Late Antique Little Ice Age.pdf
# Processing PDFs:  19%|█▉        | 28/147 [00:09<00:24,  4.87it/s]2025-06-16 22:23:59,016 - INFO - Loading cached results for: Pham et al. - 2022 - Nutrition in Abrupt Sunlight Reduction Scenarios Envisioning Feasible Balanced Diets on Resilient F.pdf
# Processing PDFs:  20%|█▉        | 29/147 [00:09<00:24,  4.79it/s]2025-06-16 22:23:59,234 - INFO - Loading cached results for: Chenarides et al. - 2021 - COVID‐19 and Food Supply Chains.pdf
# 2025-06-16 22:23:59,284 - INFO - Loading cached results for: Kim et al. - 2021 - Which National Factors Are Most Influential in the Spread of COVID-19 05.00.57.pdf
# Processing PDFs:  21%|██        | 31/147 [00:09<00:18,  6.11it/s]2025-06-16 22:23:59,449 - INFO - Loading cached results for: Arnscheidt et al. - 2024 - Systemic contributions to global catastrophic risk.pdf
# Processing PDFs:  22%|██▏       | 32/147 [00:11<00:56,  2.04it/s]2025-06-16 22:24:00,964 - INFO - Loading cached results for: Wilson et al. - 2022 - Food Security after Nuclear Winter A Preliminary Agricultural Sector Analysis for Aotearoa New Zeal.pdf
# Processing PDFs:  22%|██▏       | 33/147 [00:11<00:48,  2.33it/s]2025-06-16 22:24:01,216 - INFO - Loading cached results for: Fisher and Sandberg - 2022 - A safe governance space for humanity necessary conditions for the governance of Global Catastrophic.pdf
# Processing PDFs:  23%|██▎       | 34/147 [00:11<00:46,  2.41it/s]2025-06-16 22:24:01,591 - INFO - Loading cached results for: Self - 2006 - The effects and consequences of very large explosive volcanic eruptions.pdf
# Processing PDFs:  24%|██▍       | 35/147 [00:11<00:38,  2.91it/s]2025-06-16 22:24:01,752 - INFO - Loading cached results for: Turchin and Denkenberger - 2018 - Surviving global risks through the preservation of humanity's data on the Moon.pdf
# Processing PDFs:  24%|██▍       | 36/147 [00:12<00:39,  2.80it/s]2025-06-16 22:24:02,143 - INFO - Loading cached results for: García Martínez et al. - 2022 - Methane Single Cell Protein Potential to Secure a Global Protein Supply Against Catastrophic Food S.pdf
# Processing PDFs:  25%|██▌       | 37/147 [00:12<00:33,  3.26it/s]2025-06-16 22:24:02,324 - INFO - Loading cached results for: Boyd and Wilson - 2021 - Optimizing Island Refuges against global Catastrophic and Existential Biological Threats Priorities.pdf
# Processing PDFs:  26%|██▌       | 38/147 [00:12<00:27,  3.91it/s]2025-06-16 22:24:02,455 - INFO - Loading cached results for: OECD - 2011 - Future Global Shocks Improving Risk Governance.pdf
# Processing PDFs:  27%|██▋       | 39/147 [00:15<01:57,  1.09s/it]2025-06-16 22:24:05,534 - INFO - Loading cached results for: Franco and Hansen - 2010 - The State of Biopreparedness Lessons from Leaders, Proposals for Progress.pdf
# 2025-06-16 22:24:05,575 - INFO - Loading cached results for: Denkenberger and Blair - 2018 - Interventions that may prevent or mollify supervolcanic eruptions.pdf
# Processing PDFs:  28%|██▊       | 41/147 [00:15<01:08,  1.55it/s]2025-06-16 22:24:05,779 - INFO - Loading cached results for: Throup et al. - 2022 - Rapid repurposing of pulp and paper mills, biorefineries, and breweries for lignocellulosic sugar pr.pdf
# Processing PDFs:  29%|██▊       | 42/147 [00:16<01:18,  1.34it/s]2025-06-16 22:24:06,844 - INFO - Loading cached results for: Beggan et al. - 2018 - The ground effects of severe space weather 05.00.57.pdf
# 2025-06-16 22:24:06,939 - INFO - Loading cached results for: Grime - 1986 - Predictions of terrestrial vegetation responses to nuclear winter conditions.pdf
# Processing PDFs:  30%|██▉       | 44/147 [00:17<00:49,  2.08it/s]2025-06-16 22:24:07,040 - INFO - Loading cached results for: Winstead and Jacobson - 2022 - Forest Resource Availability After Nuclear War or Other Sun‐Blocking Catastrophes.pdf
# 2025-06-16 22:24:07,132 - INFO - Loading cached results for: Wilson et al. - 2023 - Mathematical optimization of frost resistant crop production to ensure food supply during a nuclear.pdf
# Processing PDFs:  31%|███▏      | 46/147 [00:17<00:37,  2.67it/s]2025-06-16 22:24:07,428 - INFO - Loading cached results for: Jabareen - 2012 - Vulnerability of cities to extreme space weather events A new frontier of a multidisciplinary urban.pdf
# 2025-06-16 22:24:07,469 - INFO - Loading cached results for: Boyd et al. - 2020 - Validation analysis of Global Health Security Index (GHSI) scores 2019.pdf
# Processing PDFs:  33%|███▎      | 48/147 [00:17<00:26,  3.74it/s]2025-06-16 22:24:07,559 - INFO - Loading cached results for: Papale and Marzocchi - 2019 - Volcanic threats to global society.pdf
# 2025-06-16 22:24:07,630 - INFO - Loading cached results for: Beard et al. - 2023 - The Era of Global Risk An Introduction to Existential Risk Studies.pdf
# Processing PDFs:  34%|███▍      | 50/147 [00:19<00:43,  2.24it/s]2025-06-16 22:24:09,182 - INFO - Loading cached results for: Baum and Adams - 2023 - Pandemic refuges Lessons from 2 years of COVID‐19.pdf
# 2025-06-16 22:24:09,274 - INFO - Loading cached results for: Gheorghe et al. - 2018 - New Dimensions for a Challenging Security Environment Growing Exposure to Critical Space Infrastruc.pdf
# Processing PDFs:  35%|███▌      | 52/147 [00:19<00:32,  2.92it/s]2025-06-16 22:24:09,421 - INFO - Loading cached results for: Cook and Jóhannsdóttir - 2021 - Impacts, Systemic Risk and National Response Measures Concerning COVID-19—The Island Case Studies of.pdf
# Processing PDFs:  36%|███▌      | 53/147 [00:19<00:28,  3.30it/s]2025-06-16 22:24:09,552 - INFO - Loading cached results for: Early and Asal - 2014 - Nuclear Weapons and Existential Threats Insights from a Comparative Analysis of Nuclear-Armed State.pdf
# Processing PDFs:  37%|███▋      | 54/147 [00:19<00:24,  3.84it/s]2025-06-16 22:24:09,655 - INFO - Loading cached results for: Moosa and Khatatbeh - 2021 - The density paradox Are densely‐populated regions more vulnerable to Covid‐19.pdf
# Processing PDFs:  37%|███▋      | 55/147 [00:20<00:26,  3.42it/s]2025-06-16 22:24:10,054 - INFO - Loading cached results for: Alexander et al. - 2017 - Tambora and the mackerel year Phenology and fisheries during an extreme climate event.pdf
# Processing PDFs:  38%|███▊      | 56/147 [00:22<01:22,  1.10it/s]2025-06-16 22:24:12,827 - INFO - Loading cached results for: Heyvaert - 2022 - Governing Intersystemic Systemic Risks Lessons from Covid and Climate Change.pdf
# Processing PDFs:  39%|███▉      | 57/147 [00:23<01:05,  1.38it/s]2025-06-16 22:24:13,032 - INFO - Loading cached results for: Turchin and Green - 2019 - Islands as refuges for surviving global catastrophes.pdf
# Processing PDFs:  39%|███▉      | 58/147 [00:23<00:50,  1.78it/s]2025-06-16 22:24:13,165 - INFO - Loading cached results for: García Martínez et al. - 2024 - Resilient foods for preventing global famine a review of food supply interventions for global catas 05.00.57.pdf
# Processing PDFs:  40%|████      | 59/147 [00:23<00:48,  1.81it/s]2025-06-16 22:24:13,691 - INFO - Loading cached results for: Mills et al. - 2014 - Multidecadal global cooling and unprecedented ozone loss following a regional nuclear conflict 05.00.57.pdf
# Processing PDFs:  41%|████      | 60/147 [00:25<01:18,  1.11it/s]2025-06-16 22:24:15,449 - INFO - Loading cached results for: Wilson et al. - 2023 - Food supply during nuclear winter Mathematical optimization of frost resistant crop production for.pdf
# Processing PDFs:  41%|████▏     | 61/147 [00:25<01:01,  1.40it/s]2025-06-16 22:24:15,710 - INFO - Loading cached results for: Denkenberger and Pearce - 2018 - Cost-effectiveness of interventions for alternate food in the United States to address agricultural.pdf
# Processing PDFs:  42%|████▏     | 62/147 [00:26<00:49,  1.71it/s]2025-06-16 22:24:15,988 - INFO - Loading cached results for: Baum - 2015 - Risk and resilience for unknown, unquantifiable, systemic, and unlikelycatastrophic threats.pdf
# Processing PDFs:  43%|████▎     | 63/147 [00:26<00:38,  2.18it/s]2025-06-16 22:24:16,142 - INFO - Loading cached results for: Rose et al. - 2021 - Analysing COVID-19 outcomes in the context of the 2019 Global Health Security (GHS) Index 05.00.57.pdf
# Processing PDFs:  44%|████▎     | 64/147 [00:26<00:29,  2.81it/s]2025-06-16 22:24:16,255 - INFO - Loading cached results for: Denkenberger and Pearce - 2015 - Feeding everyone Solving the food crisis in event of global catastrophes that kill crops or obscure.pdf
# Processing PDFs:  44%|████▍     | 65/147 [00:26<00:25,  3.23it/s]2025-06-16 22:24:16,456 - INFO - Loading cached results for: Pescaroli et al. - 2018 - Increasing resilience to cascading events The M.OR.D.OR. scenario 05.00.57.pdf
# Processing PDFs:  45%|████▍     | 66/147 [00:26<00:20,  4.04it/s]2025-06-16 22:24:16,558 - INFO - Loading cached results for: Donovan and Oppenheimer - 2016 - Imagining the Unimaginable Communicating Extreme Volcanic Risk.pdf
# 2025-06-16 22:24:16,642 - INFO - Loading cached results for: Craig et al. - 2020 - Risk of COVID-19 importation to the Pacific islands through global air travel.pdf
# Processing PDFs:  46%|████▋     | 68/147 [00:26<00:13,  6.05it/s]2025-06-16 22:24:16,695 - INFO - Loading cached results for: Coupe et al. - 2019 - Nuclear Winter Responses to Nuclear War Between the United States and Russia in the Whole Atmosphere.pdf
# Processing PDFs:  47%|████▋     | 69/147 [00:27<00:13,  5.78it/s]2025-06-16 22:24:16,891 - INFO - Loading cached results for: Denkenberger and Pearce - 2015 - Serious Prepping A Guide to Necessary Research.pdf
# 2025-06-16 22:24:16,944 - INFO - Loading cached results for: Herwix et al. - 2023 - What Happens When the Machines Stop Uncovering the Risk of Digital Fragility as the Achilles’ Heel.pdf
# Processing PDFs:  48%|████▊     | 71/147 [00:27<00:20,  3.79it/s]2025-06-16 22:24:17,678 - INFO - Loading cached results for: Saulnier et al. - 2022 - Re-evaluating Our Knowledge of Health System Resilience During COVID-19 Lessons From the First Two.pdf
# Processing PDFs:  49%|████▉     | 72/147 [00:28<00:20,  3.63it/s]2025-06-16 22:24:17,990 - INFO - Loading cached results for: Moersdorf et al. - 2024 - The Fragile State of Industrial Agriculture Estimating Crop Yield Reductions in a Global Catastroph 05.00.57.pdf
# Processing PDFs:  50%|████▉     | 73/147 [00:28<00:18,  3.93it/s]2025-06-16 22:24:18,181 - INFO - Loading cached results for: Mani et al. - 2023 - 6. Natural Global Catastrophic Risks.pdf
# Processing PDFs:  50%|█████     | 74/147 [00:28<00:16,  4.49it/s]2025-06-16 22:24:18,314 - INFO - Loading cached results for: Duong et al. - 2022 - Strengthening national capacities for pandemic preparedness a cross-country analysis of COVID-19 ca.pdf
# Processing PDFs:  51%|█████     | 75/147 [00:28<00:13,  5.19it/s]2025-06-16 22:24:18,426 - INFO - Loading cached results for: Eastwood et al. - 2017 - The Economic Impact of Space Weather Where Do We Stand.pdf
# Processing PDFs:  52%|█████▏    | 76/147 [00:28<00:11,  5.97it/s]2025-06-16 22:24:18,528 - INFO - Loading cached results for: Buzulukova and Tsurutani - 2022 - Space Weather From solar origins to risks and hazards evolving in time.pdf
# Processing PDFs:  52%|█████▏    | 77/147 [00:28<00:13,  5.30it/s]2025-06-16 22:24:18,770 - INFO - Loading cached results for: Schrijver - 2015 - Socio‐Economic Hazards and Impacts of Space Weather The Important Range Between Mild and Extreme 05.00.57.pdf
# 2025-06-16 22:24:18,825 - INFO - Loading cached results for: Winstead et al. - 2023 - Valorizing staple Native American food plants as a food resilience resource.pdf
# Processing PDFs:  54%|█████▎    | 79/147 [00:29<00:12,  5.45it/s]2025-06-16 22:24:19,124 - INFO - Loading cached results for: Boyd and Wilson - 2024 - Combining Urban and Peri-Urban Agriculture for Resilience to Global Catastrophic Risks Disrupting Tr.pdf
# Processing PDFs:  54%|█████▍    | 80/147 [00:29<00:13,  5.02it/s]2025-06-16 22:24:19,372 - INFO - Loading cached results for: Boyd and Wilson - 2023 - Island refuges for surviving nuclear winter and other abrupt sunlight‐reducing catastrophes.pdf
# Processing PDFs:  55%|█████▌    | 81/147 [00:29<00:13,  5.05it/s]2025-06-16 22:24:19,567 - INFO - Loading cached results for: Arsenović et al. - 2024 - Global impacts of an extreme solar particle event under different geomagnetic field strengths.pdf
# Processing PDFs:  56%|█████▌    | 82/147 [00:29<00:13,  4.70it/s]2025-06-16 22:24:19,819 - INFO - Loading cached results for: Boyd et al. - 2020 - Border closure for island nations Analysis of pandemic and bioweapon‐related threats suggests some 05.00.57.pdf
# 2025-06-16 22:24:19,855 - INFO - Loading cached results for: Liu et al. - 2020 - Apocalypse Now Initial Lessons from the Covid-19 Pandemic for the Governance of Existential and Gl.pdf
# Processing PDFs:  57%|█████▋    | 84/147 [00:30<00:09,  6.64it/s]2025-06-16 22:24:19,959 - INFO - Loading cached results for: Wang and Lyu - 2023 - Research on the Compilation of a Composite Index from the Perspective of Public Value—The Case of th.pdf
# Processing PDFs:  58%|█████▊    | 85/147 [00:30<00:10,  6.00it/s]2025-06-16 22:24:20,178 - INFO - Loading cached results for: Ramírez Varela et al. - 2023 - Assessing pandemic preparedness, response, and lessons learned from the COVID-19 pandemic in four so.pdf
# Processing PDFs:  59%|█████▊    | 86/147 [00:30<00:11,  5.54it/s]2025-06-16 22:24:20,399 - INFO - Loading cached results for: Asian Development Bank - 2024 - What Has COVID-19 Taught Us About Asia’s Health Emergency Preparedness and Response.pdf
# Processing PDFs:  59%|█████▉    | 87/147 [00:31<00:25,  2.35it/s]2025-06-16 22:24:21,504 - INFO - Loading cached results for: Nuzzo and Ledesma - 2023 - Why Did the Best Prepared Country in the World Fare So Poorly during COVID.pdf
# Processing PDFs:  60%|█████▉    | 88/147 [00:33<00:53,  1.11it/s]2025-06-16 22:24:23,650 - INFO - Loading cached results for: Miller et al. - 2024 - Can foraging for earthworms significantly reduce global famine in a catastrophe.pdf
# Processing PDFs:  61%|██████    | 89/147 [00:34<00:52,  1.11it/s]2025-06-16 22:24:24,570 - INFO - Loading cached results for: De Amorim et al. - 2018 - The nexus between water, energy, and food in the context of the global risks An analysis of the int.pdf
# Processing PDFs:  61%|██████    | 90/147 [00:34<00:39,  1.46it/s]2025-06-16 22:24:24,707 - INFO - Loading cached results for: Johnson et al. - 2016 - Review of mitigation technologies for terrestrial power grids against space weather effects.pdf
# 2025-06-16 22:24:24,784 - INFO - Loading cached results for: Fry - 2012 - The risks and impacts of space weather Policy recommendations and initiatives.pdf
# Processing PDFs:  63%|██████▎   | 92/147 [00:34<00:22,  2.48it/s]2025-06-16 22:24:24,825 - INFO - Loading cached results for: Toon et al. - 1997 - Environmental perturbations caused by the impacts of asteroids and comets.pdf
# 2025-06-16 22:24:24,847 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,847 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,863 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,864 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,868 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,869 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,876 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,877 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,877 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,877 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,878 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,878 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,878 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,914 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,914 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,932 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,932 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,932 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,933 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,933 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,933 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,934 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,934 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,936 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,936 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,940 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,940 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,956 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,981 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,982 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,983 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,983 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,984 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,984 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,992 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,992 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,993 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,993 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,993 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,993 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,993 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,995 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,995 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,996 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,996 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,996 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:24,996 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,005 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,005 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,007 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,007 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,008 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,008 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,020 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,020 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,020 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,020 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,021 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,021 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,021 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,021 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,022 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,023 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,023 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,024 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,024 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,043 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,044 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,055 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,055 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,086 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,094 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,094 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,095 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,095 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,095 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,096 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,096 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,096 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,097 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,097 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,129 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,129 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,172 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,172 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,172 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,174 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,174 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,208 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,208 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,215 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,216 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,216 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,216 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,217 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,217 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,217 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,218 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,218 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,218 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,219 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,219 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,220 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,220 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,221 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,223 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,223 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,249 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,250 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,250 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,250 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,251 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,251 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,277 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,277 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,291 - WARNING - Unexpected escaped string: "
# 2025-06-16 22:24:25,291 - WARNING - Unexpected escaped string: "
# Processing PDFs:  63%|██████▎   | 93/147 [00:35<00:23,  2.34it/s]2025-06-16 22:24:25,330 - INFO - Loading cached results for: Health Institute at North South University, Bangladesh et al. - 2022 - Why some Countries are more Resilient in South Asia to Confront COVID-19 Pandemic and Recovery.pdf
# Processing PDFs:  64%|██████▍   | 94/147 [00:35<00:21,  2.50it/s]2025-06-16 22:24:25,651 - INFO - Loading cached results for: Bruinen De Bruin et al. - 2020 - Initial impacts of global risk mitigation measures taken during the combatting of the COVID-19 pande.pdf
# 2025-06-16 22:24:25,733 - INFO - Loading cached results for: Boyd and Wilson - 2021 - Anticipatory Governance for Preventing and Mitigating Catastrophic and Existential Risks 05.00.57.pdf
# Processing PDFs:  65%|██████▌   | 96/147 [00:36<00:14,  3.52it/s]2025-06-16 22:24:25,904 - INFO - Loading cached results for: Oughton et al. - 2017 - Quantifying the daily economic impact of extreme space weather due to failure in electricity transmi.pdf
# Processing PDFs:  66%|██████▌   | 97/147 [00:37<00:31,  1.60it/s]2025-06-16 22:24:27,652 - INFO - Loading cached results for: Li and Denkenberger - 2022 - Risk Analysis and Corrosion Prevention during Industrial Power Failure.pdf
# Processing PDFs:  67%|██████▋   | 98/147 [00:38<00:27,  1.79it/s]2025-06-16 22:24:28,015 - INFO - Loading cached results for: Cicilio et al. - 2021 - Resilience in an Evolving Electrical Grid.pdf
# Processing PDFs:  67%|██████▋   | 99/147 [00:38<00:21,  2.23it/s]2025-06-16 22:24:28,156 - INFO - Loading cached results for: Wilson et al. - 2023 - Impact of the Tambora volcanic eruption of 1815 on islands and relevance to future sunlight-blocking.pdf
# Processing PDFs:  68%|██████▊   | 100/147 [00:38<00:19,  2.45it/s]2025-06-16 22:24:28,453 - INFO - Loading cached results for: Boyd et al. - 2024 - Mitigating imported fuel dependency in agricultural production Case study of an island nation's vul 05.00.57.pdf
# Processing PDFs:  69%|██████▊   | 101/147 [00:39<00:25,  1.81it/s]2025-06-16 22:24:29,372 - INFO - Loading cached results for: García Martínez et al. - 2021 - Potential of microbial electrosynthesis for contributing to food production using CO2 during global.pdf
# Processing PDFs:  69%|██████▉   | 102/147 [00:39<00:23,  1.91it/s]2025-06-16 22:24:29,826 - INFO - Loading cached results for: Maher and Baum - 2013 - Adaptation to and Recovery from Global Catastrophe.pdf
# Processing PDFs:  70%|███████   | 103/147 [00:40<00:18,  2.38it/s]2025-06-16 22:24:29,993 - INFO - Loading cached results for: Mottaghi et al. - 2023 - Yield and Toxin Analysis of Leaf Protein Concentrate from Common North American Coniferous Trees.pdf
# 2025-06-16 22:24:30,081 - INFO - Loading cached results for: Brozović - 2023 - Societal collapse A literature review.pdf
# Processing PDFs:  71%|███████▏  | 105/147 [00:40<00:17,  2.40it/s]2025-06-16 22:24:30,818 - INFO - Loading cached results for: Jehn et al. - 2024 - Seaweed as a Resilient Food Solution After a Nuclear War 05.00.57.pdf
# Processing PDFs:  72%|███████▏  | 106/147 [00:41<00:14,  2.74it/s]2025-06-16 22:24:31,023 - INFO - Loading cached results for: Tähtinen et al. - 2024 - Landscape and domains of possible future threats from a societal point of view.pdf
# Processing PDFs:  73%|███████▎  | 107/147 [00:41<00:12,  3.19it/s]2025-06-16 22:24:31,188 - INFO - Loading cached results for: Scherrer et al. - 2020 - Marine wild-capture fisheries after nuclear war.pdf
# Processing PDFs:  73%|███████▎  | 108/147 [00:41<00:10,  3.72it/s]2025-06-16 22:24:31,337 - INFO - Loading cached results for: Baum - 2015 - Confronting the threat of nuclear winter 05.00.57.pdf
# 2025-06-16 22:24:31,417 - INFO - Loading cached results for: Kufoof et al. - 2024 - Learning From COVID-19 What Would It Take to Be Better Prepared in the Eastern Mediterranean Region.pdf
# Processing PDFs:  75%|███████▍  | 110/147 [00:41<00:07,  4.98it/s]2025-06-16 22:24:31,561 - INFO - Loading cached results for: Levent et al. - 2022 - A risk‐based mutual insurance premium framework for establishing indices of vulnerability to the int.pdf
# Processing PDFs:  76%|███████▌  | 111/147 [00:41<00:06,  5.17it/s]2025-06-16 22:24:31,732 - INFO - Loading cached results for: Morhard - 2019 - Priorities for Public–Private Cooperation to Mitigate Risk and Impact of Global Catastrophic Biologi.pdf
# 2025-06-16 22:24:31,769 - INFO - Loading cached results for: Hall et al. - 2022 - Operation Warp Speed and the Countermeasures Acceleration Group— A Twenty-first Century Manhattan Pr 05.00.57.pdf
# Processing PDFs:  77%|███████▋  | 113/147 [00:43<00:14,  2.42it/s]2025-06-16 22:24:33,205 - INFO - Loading cached results for: Rivers et al. - 2022 - Deployment of Resilient Foods Can Greatly Reduce Faminein an Abrupt Sunlight Reduction Scenario 05.00.57.pdf
# Processing PDFs:  78%|███████▊  | 114/147 [00:43<00:13,  2.53it/s]2025-06-16 22:24:33,539 - INFO - Loading cached results for: Baker et al. - 2014 - Predicting and mitigating socio-economic impacts of extreme space weather benefits of improved fore.pdf
# 2025-06-16 22:24:33,634 - INFO - Loading cached results for: Black et al. - 2021 - Global climate disruption and regional climate shelters after the Toba supereruption.pdf
# Processing PDFs:  79%|███████▉  | 116/147 [00:44<00:10,  2.97it/s]2025-06-16 22:24:34,030 - INFO - Loading cached results for: Xu et al. - 2023 - Possible Mitigation of Global Cooling due to Supervolcanic Eruption via Intentional Release of Fluor.pdf
# Processing PDFs:  80%|███████▉  | 117/147 [00:44<00:09,  3.31it/s]2025-06-16 22:24:34,208 - INFO - Loading cached results for: Manheim and Denkenberger - 2020 - Review of potential high-leverage and inexpensive mitigations for reducing risk in epidemics and pan.pdf
# Processing PDFs:  80%|████████  | 118/147 [00:44<00:09,  3.14it/s]2025-06-16 22:24:34,581 - INFO - Loading cached results for: Fischbacher‐Smith and Adekola - 2022 - Lessons learned from COVID‐19 and the implications for resilience research, policy and practice.pdf
# Processing PDFs:  81%|████████  | 119/147 [00:44<00:07,  3.76it/s]2025-06-16 22:24:34,690 - INFO - Loading cached results for: Hochman et al. - 2022 - Economic incentives modify agricultural impacts of nuclear war 05.00.57.pdf
# Processing PDFs:  82%|████████▏ | 120/147 [00:45<00:10,  2.57it/s]2025-06-16 22:24:35,422 - INFO - Loading cached results for: Chaudhry et al. - 2020 - A country level analysis measuring the impact of government actions, country preparedness and socioe.pdf
# Processing PDFs:  82%|████████▏ | 121/147 [00:45<00:08,  2.99it/s]2025-06-16 22:24:35,610 - INFO - Loading cached results for: Maruta and Moyo - 2022 - Impact of pre-COVID-19 epidemic preparedness on the trajectory of the pandemic in African countries.pdf
# Processing PDFs:  83%|████████▎ | 122/147 [00:45<00:06,  3.57it/s]2025-06-16 22:24:35,752 - INFO - Loading cached results for: Futter et al. - 2020 - Nuclear war, public health, the COVID-19 epidemic Lessons for prevention, preparation, mitigation,.pdf
# Processing PDFs:  84%|████████▎ | 123/147 [00:46<00:06,  3.69it/s]2025-06-16 22:24:36,000 - INFO - Loading cached results for: Markovic et al. - 2022 - GHSI COVID-19 puzzle did highly developed countries indeed fare worse.pdf
# Processing PDFs:  84%|████████▍ | 124/147 [00:46<00:05,  3.86it/s]2025-06-16 22:24:36,230 - INFO - Loading cached results for: Barrett - 2017 - Value of Global Catastrophic Risk (GCR) Information Cost-Effectiveness-Based Approach for GCR Reduc.pdf
# Processing PDFs:  85%|████████▌ | 125/147 [00:46<00:05,  4.16it/s]2025-06-16 22:24:36,425 - INFO - Loading cached results for: Baum - 2009 - Global Catastrophic Risks edited by Nick Bostrom & Milan Ćirković.pdf
# 2025-06-16 22:24:36,441 - INFO - Loading cached results for: García Martínez et al. - 2022 - Synthetic fat from petroleum as a resilient food for global catastrophes Preliminary techno-economi.pdf
# Processing PDFs:  86%|████████▋ | 127/147 [00:48<00:09,  2.02it/s]2025-06-16 22:24:38,024 - INFO - Loading cached results for: Oughton et al. - 2019 - A Risk Assessment Framework for the Socioeconomic Impacts of Electricity Transmission Infrastructure.pdf
# Processing PDFs:  87%|████████▋ | 128/147 [00:48<00:08,  2.18it/s]2025-06-16 22:24:38,372 - INFO - Loading cached results for: Handan Dökmeci - 2020 - BİYOLOJİK SİLAH BİYOLOJİK SAVAŞLAR, PANDEMİLER VE COVID-19.pdf
# Processing PDFs:  88%|████████▊ | 129/147 [00:48<00:07,  2.34it/s]2025-06-16 22:24:38,709 - WARNING - File RAND_PEA1481-2.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:38,709 - INFO - Processing RAND_PEA1481-2.pdf...
# 2025-06-16 22:24:38,713 - ERROR - Error processing RAND_PEA1481-2.pdf: PyCryptodome is required for AES algorithm
# 2025-06-16 22:24:38,720 - WARNING - File Maffei et al. - 2023 - Climatological predictions of the auroral zone locations driven by moderate and severe space weather.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:38,720 - INFO - Processing Maffei et al. - 2023 - Climatological predictions of the auroral zone locations driven by moderate and severe space weather.pdf...
# 2025-06-16 22:24:44,009 - INFO - Extracted 60302 characters from Maffei et al. - 2023 - Climatological predictions of the auroral zone locations driven by moderate and severe space weather.pdf
# 2025-06-16 22:24:44,009 - INFO - Using cached response for Maffei et al. - 2023 - Climatological predictions of the auroral zone locations driven by moderate and severe space weather.pdf
# 2025-06-16 22:24:44,012 - INFO - Successfully processed Maffei et al. - 2023 - Climatological predictions of the auroral zone locations driven by moderate and severe space weather.pdf
# Processing PDFs:  89%|████████▉ | 131/147 [00:54<00:22,  1.38s/it]2025-06-16 22:24:44,016 - WARNING - File Da’ar and Kalmey - 2023 - The level of countries’ preparedness to health risks during Covid-19 and pre-pandemic the different 05.00.57.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:44,016 - INFO - Processing Da’ar and Kalmey - 2023 - The level of countries’ preparedness to health risks during Covid-19 and pre-pandemic the different 05.00.57.pdf...
# 2025-06-16 22:24:44,323 - INFO - Extracted 64009 characters from Da’ar and Kalmey - 2023 - The level of countries’ preparedness to health risks during Covid-19 and pre-pandemic the different 05.00.57.pdf
# 2025-06-16 22:24:44,323 - INFO - Using cached response for Da’ar and Kalmey - 2023 - The level of countries’ preparedness to health risks during Covid-19 and pre-pandemic the different 05.00.57.pdf
# 2025-06-16 22:24:44,327 - INFO - Successfully processed Da’ar and Kalmey - 2023 - The level of countries’ preparedness to health risks during Covid-19 and pre-pandemic the different 05.00.57.pdf
# Processing PDFs:  90%|████████▉ | 132/147 [00:54<00:16,  1.13s/it]2025-06-16 22:24:44,330 - WARNING - File Haldon et al. - 2020 - Lessons from the past, policies for the future resilience and sustainability in past crises.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:44,330 - INFO - Processing Haldon et al. - 2020 - Lessons from the past, policies for the future resilience and sustainability in past crises.pdf...
# 2025-06-16 22:24:44,426 - INFO - Extracted 60454 characters from Haldon et al. - 2020 - Lessons from the past, policies for the future resilience and sustainability in past crises.pdf
# 2025-06-16 22:24:44,426 - INFO - Using cached response for Haldon et al. - 2020 - Lessons from the past, policies for the future resilience and sustainability in past crises.pdf
# 2025-06-16 22:24:44,430 - INFO - Successfully processed Haldon et al. - 2020 - Lessons from the past, policies for the future resilience and sustainability in past crises.pdf
# Processing PDFs:  90%|█████████ | 133/147 [00:54<00:12,  1.15it/s]2025-06-16 22:24:44,433 - WARNING - File Paudel et al. - 2023 - COVID-19 Pandemic, Climate Change, and Conflicts on Agriculture A Trio of Challenges to Global Food.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:44,433 - INFO - Processing Paudel et al. - 2023 - COVID-19 Pandemic, Climate Change, and Conflicts on Agriculture A Trio of Challenges to Global Food.pdf...
# 2025-06-16 22:24:44,580 - INFO - Extracted 102949 characters from Paudel et al. - 2023 - COVID-19 Pandemic, Climate Change, and Conflicts on Agriculture A Trio of Challenges to Global Food.pdf
# 2025-06-16 22:24:44,580 - INFO - Using cached response for Paudel et al. - 2023 - COVID-19 Pandemic, Climate Change, and Conflicts on Agriculture A Trio of Challenges to Global Food.pdf
# 2025-06-16 22:24:44,584 - INFO - Successfully processed Paudel et al. - 2023 - COVID-19 Pandemic, Climate Change, and Conflicts on Agriculture A Trio of Challenges to Global Food.pdf
# Processing PDFs:  91%|█████████ | 134/147 [00:54<00:08,  1.46it/s]2025-06-16 22:24:44,587 - WARNING - File Nazari et al. - 2022 - Critical Appraisal of the Coronavirus Preparedness among Countries using the Global Health Security.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:44,587 - INFO - Processing Nazari et al. - 2022 - Critical Appraisal of the Coronavirus Preparedness among Countries using the Global Health Security.pdf...
# 2025-06-16 22:24:44,910 - INFO - Extracted 39474 characters from Nazari et al. - 2022 - Critical Appraisal of the Coronavirus Preparedness among Countries using the Global Health Security.pdf
# 2025-06-16 22:24:44,910 - INFO - Using cached response for Nazari et al. - 2022 - Critical Appraisal of the Coronavirus Preparedness among Countries using the Global Health Security.pdf
# 2025-06-16 22:24:44,913 - INFO - Successfully processed Nazari et al. - 2022 - Critical Appraisal of the Coronavirus Preparedness among Countries using the Global Health Security.pdf
# Processing PDFs:  92%|█████████▏| 135/147 [00:55<00:07,  1.71it/s]2025-06-16 22:24:44,917 - WARNING - File Baum - 2023 - Assessing natural global catastrophic risks.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:44,917 - INFO - Processing Baum - 2023 - Assessing natural global catastrophic risks.pdf...
# 2025-06-16 22:24:45,043 - INFO - Extracted 74141 characters from Baum - 2023 - Assessing natural global catastrophic risks.pdf
# 2025-06-16 22:24:45,044 - INFO - Using cached response for Baum - 2023 - Assessing natural global catastrophic risks.pdf
# 2025-06-16 22:24:45,047 - INFO - Successfully processed Baum - 2023 - Assessing natural global catastrophic risks.pdf
# Processing PDFs:  93%|█████████▎| 136/147 [00:55<00:05,  2.18it/s]2025-06-16 22:24:45,050 - WARNING - File Su et al. - 2023 - The future of the food supply chain A systematic literature review and research directions towards.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:45,050 - INFO - Processing Su et al. - 2023 - The future of the food supply chain A systematic literature review and research directions towards.pdf...
# 2025-06-16 22:24:45,161 - INFO - Extracted 63634 characters from Su et al. - 2023 - The future of the food supply chain A systematic literature review and research directions towards.pdf
# 2025-06-16 22:24:45,161 - INFO - Using cached response for Su et al. - 2023 - The future of the food supply chain A systematic literature review and research directions towards.pdf
# 2025-06-16 22:24:45,165 - INFO - Successfully processed Su et al. - 2023 - The future of the food supply chain A systematic literature review and research directions towards.pdf
# Processing PDFs:  93%|█████████▎| 137/147 [00:55<00:03,  2.77it/s]2025-06-16 22:24:45,168 - WARNING - File Bayram and Yurtsever - 2021 - Efficiency Evaluation of European Countries in terms of COVID-19.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:45,168 - INFO - Processing Bayram and Yurtsever - 2021 - Efficiency Evaluation of European Countries in terms of COVID-19.pdf...
# 2025-06-16 22:24:45,344 - INFO - Extracted 35968 characters from Bayram and Yurtsever - 2021 - Efficiency Evaluation of European Countries in terms of COVID-19.pdf
# 2025-06-16 22:24:45,344 - INFO - Using cached response for Bayram and Yurtsever - 2021 - Efficiency Evaluation of European Countries in terms of COVID-19.pdf
# 2025-06-16 22:24:45,348 - INFO - Successfully processed Bayram and Yurtsever - 2021 - Efficiency Evaluation of European Countries in terms of COVID-19.pdf
# Processing PDFs:  94%|█████████▍| 138/147 [00:55<00:02,  3.23it/s]2025-06-16 22:24:45,351 - WARNING - File Nelson et al. - 2024 - Wood Gasification A Promising Strategy to Extend Fuel Reserves after Global Catastrophic Electricit.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:45,351 - INFO - Processing Nelson et al. - 2024 - Wood Gasification A Promising Strategy to Extend Fuel Reserves after Global Catastrophic Electricit.pdf...
# 2025-06-16 22:24:45,435 - INFO - Extracted 51867 characters from Nelson et al. - 2024 - Wood Gasification A Promising Strategy to Extend Fuel Reserves after Global Catastrophic Electricit.pdf
# 2025-06-16 22:24:45,436 - INFO - Using cached response for Nelson et al. - 2024 - Wood Gasification A Promising Strategy to Extend Fuel Reserves after Global Catastrophic Electricit.pdf
# 2025-06-16 22:24:45,439 - INFO - Successfully processed Nelson et al. - 2024 - Wood Gasification A Promising Strategy to Extend Fuel Reserves after Global Catastrophic Electricit.pdf
# 2025-06-16 22:24:45,442 - WARNING - File Turchin and Patrick Green - 2017 - Aquatic refuges for surviving a global catastrophe.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:45,442 - INFO - Processing Turchin and Patrick Green - 2017 - Aquatic refuges for surviving a global catastrophe.pdf...
# 2025-06-16 22:24:45,672 - INFO - Extracted 69894 characters from Turchin and Patrick Green - 2017 - Aquatic refuges for surviving a global catastrophe.pdf
# 2025-06-16 22:24:45,673 - INFO - Using cached response for Turchin and Patrick Green - 2017 - Aquatic refuges for surviving a global catastrophe.pdf
# 2025-06-16 22:24:45,677 - INFO - Successfully processed Turchin and Patrick Green - 2017 - Aquatic refuges for surviving a global catastrophe.pdf
# Processing PDFs:  95%|█████████▌| 140/147 [00:55<00:01,  4.10it/s]2025-06-16 22:24:45,680 - WARNING - File Jehn et al. - 2024 - Food trade disruption after global catastrophes.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:45,680 - INFO - Processing Jehn et al. - 2024 - Food trade disruption after global catastrophes.pdf...
# 2025-06-16 22:24:47,194 - INFO - Extracted 137593 characters from Jehn et al. - 2024 - Food trade disruption after global catastrophes.pdf
# 2025-06-16 22:24:47,195 - INFO - Using cached response for Jehn et al. - 2024 - Food trade disruption after global catastrophes.pdf
# 2025-06-16 22:24:47,198 - INFO - Successfully processed Jehn et al. - 2024 - Food trade disruption after global catastrophes.pdf
# Processing PDFs:  96%|█████████▌| 141/147 [00:57<00:03,  1.80it/s]2025-06-16 22:24:47,202 - WARNING - File Rivers et al. - 2024 - Food system adaptation and maintaining trade could mitigate global famine in abrupt sunlight reducti.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:47,202 - INFO - Processing Rivers et al. - 2024 - Food system adaptation and maintaining trade could mitigate global famine in abrupt sunlight reducti.pdf...
# 2025-06-16 22:24:48,090 - INFO - Extracted 72399 characters from Rivers et al. - 2024 - Food system adaptation and maintaining trade could mitigate global famine in abrupt sunlight reducti.pdf
# 2025-06-16 22:24:48,090 - INFO - Using cached response for Rivers et al. - 2024 - Food system adaptation and maintaining trade could mitigate global famine in abrupt sunlight reducti.pdf
# 2025-06-16 22:24:48,093 - INFO - Successfully processed Rivers et al. - 2024 - Food system adaptation and maintaining trade could mitigate global famine in abrupt sunlight reducti.pdf
# Processing PDFs:  97%|█████████▋| 142/147 [00:58<00:03,  1.55it/s]2025-06-16 22:24:48,097 - WARNING - File Green - 2016 - Emerging technologies, catastrophic risks, and ethics three strategies for reducing risk.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:48,097 - INFO - Processing Green - 2016 - Emerging technologies, catastrophic risks, and ethics three strategies for reducing risk.pdf...
# 2025-06-16 22:24:48,191 - INFO - Extracted 44703 characters from Green - 2016 - Emerging technologies, catastrophic risks, and ethics three strategies for reducing risk.pdf
# 2025-06-16 22:24:48,191 - INFO - Using cached response for Green - 2016 - Emerging technologies, catastrophic risks, and ethics three strategies for reducing risk.pdf
# 2025-06-16 22:24:48,195 - INFO - Successfully processed Green - 2016 - Emerging technologies, catastrophic risks, and ethics three strategies for reducing risk.pdf
# Processing PDFs:  97%|█████████▋| 143/147 [00:58<00:01,  2.01it/s]2025-06-16 22:24:48,198 - WARNING - File Avin et al. - 2018 - Classifying global catastrophic risks.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:48,198 - INFO - Processing Avin et al. - 2018 - Classifying global catastrophic risks.pdf...
# 2025-06-16 22:24:48,242 - INFO - Extracted 31615 characters from Avin et al. - 2018 - Classifying global catastrophic risks.pdf
# 2025-06-16 22:24:48,242 - INFO - Using cached response for Avin et al. - 2018 - Classifying global catastrophic risks.pdf
# 2025-06-16 22:24:48,245 - INFO - Successfully processed Avin et al. - 2018 - Classifying global catastrophic risks.pdf
# 2025-06-16 22:24:48,249 - WARNING - File Liu et al. - 2018 - Governing Boring Apocalypses A new typology of existential vulnerabilities and exposures for existe.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:48,249 - INFO - Processing Liu et al. - 2018 - Governing Boring Apocalypses A new typology of existential vulnerabilities and exposures for existe.pdf...
# 2025-06-16 22:24:48,543 - INFO - Extracted 87805 characters from Liu et al. - 2018 - Governing Boring Apocalypses A new typology of existential vulnerabilities and exposures for existe.pdf
# 2025-06-16 22:24:48,543 - INFO - Using cached response for Liu et al. - 2018 - Governing Boring Apocalypses A new typology of existential vulnerabilities and exposures for existe.pdf
# 2025-06-16 22:24:48,547 - INFO - Successfully processed Liu et al. - 2018 - Governing Boring Apocalypses A new typology of existential vulnerabilities and exposures for existe.pdf
# Processing PDFs:  99%|█████████▊| 145/147 [00:58<00:00,  2.80it/s]2025-06-16 22:24:48,550 - WARNING - File Varne et al. - 2024 - The impact of abrupt sunlight reduction scenarios on renewable energy production.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:48,550 - INFO - Processing Varne et al. - 2024 - The impact of abrupt sunlight reduction scenarios on renewable energy production.pdf...
# 2025-06-16 22:24:48,863 - INFO - Extracted 58123 characters from Varne et al. - 2024 - The impact of abrupt sunlight reduction scenarios on renewable energy production.pdf
# 2025-06-16 22:24:48,864 - INFO - Using cached response for Varne et al. - 2024 - The impact of abrupt sunlight reduction scenarios on renewable energy production.pdf
# 2025-06-16 22:24:48,867 - INFO - Successfully processed Varne et al. - 2024 - The impact of abrupt sunlight reduction scenarios on renewable energy production.pdf
# Processing PDFs:  99%|█████████▉| 146/147 [00:59<00:00,  2.87it/s]2025-06-16 22:24:48,870 - WARNING - File Wong et al. - 2020 - Is the Global Health Security (GHS) Index a Significant Factor Associated with COVID-19 Control A C.pdf marked as processed but no cache found, reprocessing...
# 2025-06-16 22:24:48,871 - INFO - Processing Wong et al. - 2020 - Is the Global Health Security (GHS) Index a Significant Factor Associated with COVID-19 Control A C.pdf...
# 2025-06-16 22:24:49,528 - INFO - Extracted 45213 characters from Wong et al. - 2020 - Is the Global Health Security (GHS) Index a Significant Factor Associated with COVID-19 Control A C.pdf
# 2025-06-16 22:24:49,529 - INFO - Using cached response for Wong et al. - 2020 - Is the Global Health Security (GHS) Index a Significant Factor Associated with COVID-19 Control A C.pdf
# 2025-06-16 22:24:49,532 - INFO - Successfully processed Wong et al. - 2020 - Is the Global Health Security (GHS) Index a Significant Factor Associated with COVID-19 Control A C.pdf
# Processing PDFs: 100%|██████████| 147/147 [00:59<00:00,  2.46it/s]
